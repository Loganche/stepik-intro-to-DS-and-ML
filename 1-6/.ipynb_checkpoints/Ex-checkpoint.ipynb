# %%
import pandas as pd
import numpy as np

# %%
dota_stats = pd.read_csv('dota_hero_stats.csv')
dota_stats.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
dota_stats.loc[dota_stats.legs == 8].count()
# Out:
# Unnamed: 0        1
# attack_type       1
# id                1
# legs              1
# localized_name    1
# name              1
# primary_attr      1
# roles             1
# dtype: int64

# %%
accounts = pd.read_csv('accountancy.csv')
accounts.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
accounts.index = accounts['Unnamed: 0']
accounts = accounts.drop('Unnamed: 0', axis = 1)
accounts.head()
# Out:
#            Executor Type  Salary
# Unnamed: 0
# 0              Pupa    D      63
# 1              Pupa    A     158
# 2              Pupa    D     194
# 3              Pupa    E     109
# 4             Loopa    E     184

# %%
accounts_count = accounts.sort_values('Salary', ascending=False) \
        .groupby(['Executor', 'Type'])

# %%
dota_stats.index = dota_stats['Unnamed: 0']
dota_stats = dota_stats.drop('Unnamed: 0', axis = 1)
dota_stats.head()
# Out:
#            attack_type  id  legs  localized_name  \
# Unnamed: 0
# 0                Melee   1     2       Anti-Mage
# 1                Melee   2     2             Axe
# 2               Ranged   3     4            Bane
# 3                Melee   4     2     Bloodseeker
# 4               Ranged   5     2  Crystal Maiden
#
#                                     name primary_attr  \
# Unnamed: 0
# 0                 npc_dota_hero_antimage          agi
# 1                      npc_dota_hero_axe          str
# 2                     npc_dota_hero_bane          int
# 3              npc_dota_hero_bloodseeker          agi
# 4           npc_dota_hero_crystal_maiden          int
#
#                                                         roles
# Unnamed: 0
# 0                                ['Carry', 'Escape', 'Nuker']
# 1             ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2                 ['Support', 'Disabler', 'Nuker', 'Durable']
# ...

# %%
dota_stats.groupby(['attack_type', 'primary_attr']).count()
# Out:
#                           id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi           19    19              19    19     19
#             int            2     2               2     2      2
#             str           35    35              35    35     35
# Ranged      agi           18    18              18    18     18
#             int           40    40              40    40     40
#             str            3     3               3     3      3

# %%
seaweed = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')
seaweed.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
seaweed.describe()
# Out:
#          sucrose     alanin    citrate    glucose  oleic_acid
# count  10.000000  10.000000  10.000000  10.000000   10.000000
# mean    4.098895   3.379068   4.603042   3.346347    3.054593
# std     2.271190   2.400529   2.084948   1.094572    1.739319
# min     0.704580   0.346431   1.071920   2.272724    0.304573
# 25%     2.589835   1.353551   3.563185   2.596385    2.292285
# 50%     3.569170   3.319066   5.413716   3.292899    2.678951
# 75%     6.476373   5.272747   5.786515   3.571159    3.965826
# max     6.825467   6.881024   6.940588   6.013219    6.405165

# %%
seaweed.groupby('genus').aggregate({'sucrose':'mean', 'alanin':'mean', 'citrate':'mean', 'glucose':'mean', 'oleic_acid':'mean'})
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
seaweed.groupby('genus').alanin.describe()
# Out:
#              count      mean       std       min       25%       50%  \
# genus
# Ascophyllum    1.0  0.875429       NaN  0.875429  0.875429  0.875429
# Cladophora     3.0  3.997055  2.657050  1.648450  2.555071  3.461692
# Fucus          3.0  3.566411  3.149943  0.346431  2.028965  3.711498
# Palmaria       1.0  3.176440       NaN  3.176440  3.176440  3.176440
# Saccharina     2.0  3.524207  3.208789  1.255251  2.389729  3.524207
#
#                   75%       max
# genus
# Ascophyllum  0.875429  0.875429
# Cladophora   5.171358  6.881024
# Fucus        5.176401  6.641303
# Palmaria     3.176440  3.176440
# Saccharina   4.658685  5.793163

# %%
seaweed.groupby('group').glucose.describe()
# Out:
#        count      mean       std       min       25%       50%       75%  \
# group
# brown    6.0  3.636759  1.329570  2.272724  2.765084  3.519093  3.866782
# green    3.0  2.800276  0.516009  2.316955  2.528560  2.740165  3.041936
# red      1.0  3.242090       NaN  3.242090  3.242090  3.242090  3.242090
#
#             max
# group
# brown  6.013219
# green  3.343707
# red    3.242090
