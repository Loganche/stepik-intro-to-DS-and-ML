# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('data.txt', sep=" ")
df.head()
# Out:
#              x           y
# 0   699.831337  512.628557
# 1   709.860166  499.970925
# 2  1389.148995  697.724839
# 3   128.718001  797.496138
# 4  1401.723522  715.355083

# %%
sns.lmplot(x='x', y='y', data=df)

# %%
sns.scatterplot(x='x', y='y', data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
genome = pd.read_csv('genome_matrix.csv', index_col=0)

# %%
genome.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(data=genome, annot=True, cmap="viridis", linewidths=.5)
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
dota = pd.read_csv('dota_hero_stats.csv', index_col=0)
dota.head()
# Out:
#   attack_type  id  legs  localized_name                          name  \
# 0       Melee   1     2       Anti-Mage        npc_dota_hero_antimage
# 1       Melee   2     2             Axe             npc_dota_hero_axe
# 2      Ranged   3     4            Bane            npc_dota_hero_bane
# 3       Melee   4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4      Ranged   5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
#
#   primary_attr                                              roles
# 0          agi                       ['Carry', 'Escape', 'Nuker']
# 1          str    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2          int        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3          agi  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4          int        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
dota['cnt'] = dota.roles.str.count(',')+1
dota.cnt.describe()
# Out:
# count    117.000000
# mean       4.000000
# std        1.090713
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        6.000000
# Name: cnt, dtype: float64

# %%
sns.histplot(y='name', x='roles', data=dota)
# Out:
# <AxesSubplot:xlabel='roles', ylabel='name'>

# %%
flower = pd.read_csv('iris.csv', index_col=0)
flower.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
for col in flower:
    sns.kdeplot(x=col, data=flower)

# %%
sns.kdeplot(data=flower)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.violinplot(x='petal length', data=flower)
# Out:
# <AxesSubplot:xlabel='petal length'>

# %%
sns.pairplot(data=flower)
